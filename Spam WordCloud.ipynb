# %% [markdown]
# WordCloud is a pictorial presentation of most frequent words

# %%
# Ex: if you create a wordcloud for the hiring manager(contain most frequent words)
# you create WC on some 100 job requirement (jd) data , science , python , analytics ,cloud , gpc , java etc

# %%
df = pd.read_csv('spam.csv', encoding='cp1252')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
cloud = WordCloud(stopwords = stopwords.words('english')).generate(str(df.v2))
cloud

# %%
import matplotlib.pyplot as plt
plt.imshow(cloud)

# %%
cloud = WordCloud(stopwords = stopwords.words('english'), max_words = 100 , random_state = 236 , contour_width = 'blue').generate(str(df.v2))
plt.imshow(cloud)
